# %% [markdown]
# <a href="https://colab.research.google.com/github/divya2212001/colabs/blob/main/Copy_of_LangChain_basic_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y langgraph-prebuilt langgraph
# !pip install langchain==0.2.14 langchain-core==0.2.43 langchain-groq==0.1.5 -q
# Out:
# Found existing installation: langgraph-prebuilt 1.0.8
# Uninstalling langgraph-prebuilt-1.0.8:
#   Successfully uninstalled langgraph-prebuilt-1.0.8
# Found existing installation: langgraph 1.1.4
# Uninstalling langgraph-1.1.4:
#   Successfully uninstalled langgraph-1.1.4
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 25.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 397.1/397.1 kB 24.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 10.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.8/311.8 kB 20.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 71.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.5/65.5 kB 4.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-adk 1.28.0 requires tenacity<10.0.0,>=9.0.0, but you have tenacity 8.5.0 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# rasterio 1.5.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# jax 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# xarray-einstats 0.10.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# tobler 0.13.0 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python 4.13.0.92 requires numpy>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.51.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.38.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.

# %%
# !pip uninstall -y langgraph-prebuilt langgraph
# Out:
# WARNING: Skipping langgraph-prebuilt as it is not installed.
# WARNING: Skipping langgraph as it is not installed.

# %%
# !pip install -q --upgrade langchain langchain-groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 2.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 508.3/508.3 kB 16.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 360.2/360.2 kB 21.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-text-splitters 0.2.4 requires langchain-core<0.3.0,>=0.2.38, but you have langchain-core 1.2.27 which is incompatible.

# %%
import os
from google.colab import userdata
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq


# Retrieve the secret value as a string
os.environ["GROQ_API_KEY"] = userdata.get('GROQ_API_KEY')

# %%
# Test if your api key works

from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.3-70b-versatile")

print(llm.invoke("Explain linear regression in one paragraph"))
# Out:
# content='Linear regression is a statistical method used to model the relationship between a dependent variable (target or outcome) and one or more independent variables (predictors or features). It assumes a linear relationship between the variables, meaning that the change in the dependent variable is directly proportional to the change in the independent variable(s). The goal of linear regression is to create a best-fit line that minimizes the difference between the observed data points and the predicted values, using a linear equation of the form Y = β0 + β1X + ε, where Y is the dependent variable, X is the independent variable, β0 is the intercept, β1 is the slope, and ε is the error term. By estimating the coefficients (β0 and β1) using ordinary least squares or other methods, linear regression provides a simple yet powerful tool for predicting continuous outcomes, identifying relationships, and making informed decisions in various fields, including business, economics, and social sciences.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 191, 'prompt_tokens': 42, 'total_tokens': 233, 'completion_time': 0.506657087, 'completion_tokens_details': None, 'prompt_time': 0.010831769, 'prompt_tokens_details': None, 'queue_time': 0.235852839, 'total_time': 0.517488856}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019d6b48-93ed-79d2-a03a-351e57cdc58f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 42, 'output_tokens': 191, 'total_tokens': 233}

# %% [markdown]
# # LangChain Exercise: Manual LLM Chaining with ChatGroq
#
# ## Objective
#
# In this exercise, you will build a **multi-step LLM pipeline** using LangChain — without relying on high-level chain abstractions.
#
# You will:
# 1. Generate an explanation of a topic
# 2. Use that explanation to create quiz questions
#
# This demonstrates how **outputs from one LLM call can be used as inputs to another**.

# %% [markdown]
# Instead of using `LLMChain` or `SequentialChain`, you will implement this flow **manually** using `.invoke()`.
#
# ---
#
# ## Key Components Used
#
# ### 1. `ChatGroq`
# - Interface to large language models via Groq
# - Extremely fast inference
# - Used to generate responses from prompts
#
# ### 2. `PromptTemplate`
# - Used to create **structured and reusable prompts**
# - Allows you to insert variables dynamically into prompts
# - Helps maintain clean and consistent prompt design
#
#
# ### 3. `format()`
# - Fills in the variables inside a PromptTemplate
# - Converts the template into a final prompt string that can be sent to the LLM
#
# ### 4. `invoke()`
# - Sends the formatted prompt to the LLM
# - Executes the model and returns a response object
#
# ### 5. `content()`
# - Extracts the actual text output from the response object
# - This is what you use for the next step in the pipeline
#
#
# `Input` → `Prompt` → `LLM` → `Output` → `Next Prompt` → `LLM` → `Final Output`

# %%
from langchain_core.prompts import PromptTemplate
from langchain_groq import ChatGroq

# Initialize the ChatGroq model (LLM instance)
# parameterize model name llama-3.3-70b-versatile and temperature 0.7 (controls randomness of output)
llm = ChatGroq(model="llama-3.3-70b-versatile",temperature=0.7)


# Step 1: Explanation prompt
# Initialize prompt1 object by instantiating PromptTemplate class
# parameterize input_variables list with "topic"
# parameterize template string with "Explain {topic} in simple terms"
prompt1=PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in simple terms"
)




# Step 2: Quiz prompt
# Initialize prompt2 object by instantiating PromptTemplate class
# parameterize input_variables list with "explanation"
# parameterize template string with a "Create 2 quiz questions from this:\n{explanation}"
prompt2=PromptTemplate(
    input_variables=["explanation"],
    template="Create 2 quiz questions from this:\n{explanation}"
)




# ---- Execution (manual chaining) ----

# Step 1
# initialize formatted_prompt1 by calling .format() on prompt1
# parameterize format method with topic="KNN"
# invoke LLM using .invoke() with formatted prompt string
# store response object in response1
# extract generated text using response1.content and store in explanation
formatted_prompt1=prompt1.format(topic="KNN")
response1=llm.invoke(formatted_prompt1)
explanation=response1.content





# Step 2
# initialize formatted_prompt2 by calling .format() on prompt2
# parameterize format method with explanation from previous step
# invoke LLM using .invoke() with formatted prompt string
# store response object in response2
# extract generated text using response2.content and store in quiz
formatted_prompt2=prompt2.format(explanation=explanation)
response2=llm.invoke(formatted_prompt2)
quiz=response2.content



# Final result
# aggregate outputs into a dictionary for structured access
result = {
    "explanation": explanation,
    "quiz": quiz
}

# display final output
print(result)
# Out:
# {'explanation': '**K-Nearest Neighbors (KNN) Algorithm**\n\nKNN is a simple, yet powerful machine learning algorithm used for classification and regression tasks.\n\n**How it Works:**\n\n1. **Data Collection**: Gather a dataset with features (e.g., age, income, location) and a target variable (e.g., buyer or non-buyer).\n2. **Choose a Value for K**: Select a number of nearest neighbors (K) to consider when making predictions.\n3. **Calculate Distances**: Measure the distance between a new, unseen data point and all existing data points in the dataset.\n4. **Find Nearest Neighbors**: Identify the K data points with the shortest distances to the new data point.\n5. **Make a Prediction**: For classification, the new data point is assigned the most common class among its K nearest neighbors. For regression, the prediction is the average value of the target variable among the K nearest neighbors.\n\n**Example:**\n\nSuppose we want to predict whether someone will buy a car based on their age and income. We have a dataset with these features and a target variable (buyer or non-buyer). We choose K = 3.\n\n* A new person with age 30 and income $50,000 is added to the dataset.\n* We calculate the distances between this person and all existing data points.\n* The 3 nearest neighbors are:\n\t1. Age 28, Income $45,000, Buyer\n\t2. Age 32, Income $55,000, Buyer\n\t3. Age 25, Income $40,000, Non-buyer\n* Since 2 out of the 3 nearest neighbors are buyers, we predict that the new person will buy a car.\n\n**Advantages:**\n\n* Simple to implement\n* Handles non-linear relationships between features\n* Can be used for both classification and regression tasks\n\n**Disadvantages:**\n\n* Computationally expensive for large datasets\n* Sensitive to noise and outliers in the data\n* Requires careful selection of the value of K\n\nOverall, KNN is a versatile algorithm that can be used for a variety of machine learning tasks, and its simplicity makes it a great starting point for beginners.', 'quiz': 'Here are 2 quiz questions based on the K-Nearest Neighbors (KNN) Algorithm:\n\n1. What is the primary step in the KNN algorithm where the distance between a new, unseen data point and all existing data points in the dataset is measured?\nA) Choose a Value for K\nB) Calculate Distances\nC) Find Nearest Neighbors\nD) Make a Prediction\n\nAnswer: B) Calculate Distances\n\n2. What is a major disadvantage of the KNN algorithm, particularly when dealing with large datasets?\nA) It is unable to handle non-linear relationships between features\nB) It is sensitive to noise and outliers in the data\nC) It is computationally expensive\nD) It can only be used for classification tasks\n\nAnswer: C) It is computationally expensive'}
